# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
PATH = os.getcwd()
DATAPATH = os.path.join(PATH, "data")
filenames = {
    "X_test": "test_in - Copy.csv",
    "X_train": "train_in - Copy.csv",
    "y_test": "test_out - Copy.csv",
    "y_train": "train_out - Copy.csv",
}

# Import all data files
X_train = pd.read_csv(os.path.join(DATAPATH, filenames["X_train"]), header=None)
y_train = pd.read_csv(
    os.path.join(DATAPATH, filenames["y_train"]), header=None, names=["digit"]
)
X_test = pd.read_csv(os.path.join(DATAPATH, filenames["X_test"]), header=None)
y_test = pd.read_csv(
    os.path.join(DATAPATH, filenames["y_test"]), header=None, names=["digit"]
)

# %%
def sigmoid(x,a=1):
    return 1/(1 + np.exp(-a*x))

def dsigmoid(x,a=1):
    return sigmoid(x,a)(1-sigmoid(x,a))

def err(y,d):
    return 1/2*np.sum(np.square(y-d))

# %%
X_train['Bias'] = np.ones((len(X_train),))
X_test['Bias'] = np.ones((len(X_test),))

def rand_weights():
    return pd.DataFrame(np.random.uniform(-1,1,(257,10)))

weight_train = rand_weights()
activations = np.dot(X_train,weight_train)
activations_sigmoid = pd.DataFrame(sigmoid(activations))
y_pred = [np.argmax(row) for _,row in activations_sigmoid.iterrows()]
yreal = np.zeros((len(X_train),10))
for i in range(len(X_train)):
    j = y_train.digit[i]
    yreal[i,j] = 1

err(activations_sigmoid.iloc[0,:],yreal[0,:])
 
pd.DataFrame(activations_sigmoid)
# Out:
#                  0         1         2             3         4         5  \
# 0     6.412993e-01  0.999039  0.329673  3.969810e-07  0.994891  0.999980
# 1     9.958474e-01  0.094047  0.000113  3.999509e-01  0.026478  1.000000
# 2     3.326275e-07  0.721390  0.015750  5.064044e-04  0.998989  0.999999
# 3     1.444788e-02  0.073019  0.006268  3.776041e-05  0.999903  1.000000
# 4     4.753062e-03  0.979196  0.922327  2.654807e-04  0.991363  0.463626
# ...            ...       ...       ...           ...       ...       ...
# 1702  2.478325e-08  0.999991  0.984456  4.279449e-05  0.999186  0.999959
# 1703  2.037093e-05  1.000000  0.751681  4.761392e-02  0.978226  1.000000
# 1704  4.356836e-03  0.998242  0.007440  2.669455e-05  0.999992  0.999984
# 1705  2.590560e-06  0.999988  0.006301  1.710556e-02  0.999672  1.000000
# 1706  9.129013e-01  0.937440  0.245457  2.605875e-06  0.507772  0.998404
#
#              6         7         8             9
# 0     0.999037  0.000008  0.999568  5.283961e-01
# 1     0.989250  0.000597  0.980381  1.467154e-03
# 2     0.999216  0.000145  0.999997  4.485068e-05
# 3     0.276257  0.000010  0.985028  3.723658e-08
# 4     0.999894  0.005460  0.978364  2.027053e-06
# ...        ...       ...       ...           ...
# 1702  0.997454  0.000001  0.992101  3.995311e-06
# 1703  0.025678  0.002721  0.969935  2.634992e-05
# 1704  0.001223  0.001890  0.884264  1.615912e-08
# 1705  0.999973  0.000093  0.471860  6.930509e-08
# 1706  0.994616  0.064471  0.010098  1.038344e-01
#
# [1707 rows x 10 columns]
