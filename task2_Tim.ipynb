# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
PATH = os.getcwd()
DATAPATH = os.path.join(PATH, "data")
filenames = {
    "X_test": "test_in - Copy.csv",
    "X_train": "train_in - Copy.csv",
    "y_test": "test_out - Copy.csv",
    "y_train": "train_out - Copy.csv",
}

# Import all data files
X_train = pd.read_csv(os.path.join(DATAPATH, filenames["X_train"]), header=None)
y_train = pd.read_csv(
    os.path.join(DATAPATH, filenames["y_train"]), header=None, names=["digit"]
)
X_test = pd.read_csv(os.path.join(DATAPATH, filenames["X_test"]), header=None)
y_test = pd.read_csv(
    os.path.join(DATAPATH, filenames["y_test"]), header=None, names=["digit"]
)

# %%
def sigmoid(x,a=1):
    return 1/(1 + np.exp(-a*x))

def dsigmoid(x,a=1):
    return sigmoid(x,a)(1-sigmoid(x,a))

def err(y,d):
    return 1/2*np.sum(np.sqrt(np.square(y)-np.square(d)))

# %%
X_train['Bias'] = np.ones((len(X_train),))
X_test['Bias'] = np.ones((len(X_test),))

def rand_weights():
    return pd.DataFrame(np.random.uniform(-1,1,(257,10)))

weight_train = rand_weights()
activations = np.dot(X_train,weight_train)
activations_sigmoid = pd.DataFrame(sigmoid(activations))
y_pred = [np.argmax(row) for _,row in activations_sigmoid.iterrows()]
yreal = np.zeros((len(X_train),10))
for i in range(len(X_train)):
    j = y_train.digit[i]
    yreal[i,j] = 1

err(activations_sigmoid.iloc[0,:],yreal[0,:])

# def gradient_descent(eta=0.1):
#     return 
pd.DataFrame(activations_sigmoid)
# Out:
# c:\Users\timvd\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#              0         1             2             3         4         5  \
# 0     0.980685  0.864158  9.996329e-01  1.042510e-02  0.999834  0.999979
# 1     0.952230  0.999873  9.941035e-01  9.168902e-08  0.998681  0.606387
# 2     1.000000  0.510031  9.867627e-01  9.999993e-01  0.000001  0.999591
# 3     0.998627  0.006170  5.220245e-06  9.899260e-01  0.000390  0.999998
# 4     0.999234  0.892660  4.611793e-05  1.111165e-01  0.044777  0.999967
# ...        ...       ...           ...           ...       ...       ...
# 1702  0.999899  0.003747  7.629432e-04  9.999988e-01  0.000074  1.000000
# 1703  1.000000  0.000163  3.277164e-06  9.997793e-01  0.000007  0.999459
# 1704  0.995807  0.000648  8.425614e-05  9.816401e-01  0.000185  0.999959
# ...
